# %%
#https://colab.research.google.com/drive/1_Zs5d_ADrtxKKXYIQI-8Lb1lttet2BGS

# %% [markdown]
# Lab Hello world !

# %%
print("Hello world!")
# Out:
# Hello world!

# %%
print("hello\
hello\
hello")
# Out:
# hellohellohello

# %% [markdown]
# INput LAB!
# ใช้ input , เปลี่ยน data type และ ตรวจสอบ

# %%
age = int(input("input your age "))

print(age)
print(type(age))
# Out:
# input your age 6
# 6
# <class 'int'>

# %% [markdown]
# LAB
# Data type
# int
# string
# char
# boolean
# list
# tuple
# dictionary

# %%
type_int = 123 #int 
type_str = "siwarat " #string
type_chr = 'A' #Char
type_boolean = True #boolean true false
type_list = list([1,2,3,4]) #list [1,2,3,4]
type_tuple = tuple([1,2,3,4])#tuple (1,2,3,4)
type_dict = {"ger":1,
             "lol":2 } #dict{}
print(type_dict)
print(type_tuple)
print(type_list)
print(type_int)
print(type_boolean)
print(type_str)
print(type_chr)
# Out:
# {'ger': 1, 'lol': 2}
# (1, 2, 3, 4)
# [1, 2, 3, 4]
# 123
# True
# siwarat
# A

# %% [markdown]
# ## ***Function  in python***
# สรุป

# %%
agrument1 = "siwa"
agrument2 = "rat"
def fun_name(parameter1 ="ger" , parameter2 = "lol"):
  print(parameter1,parameter2)
fun_name(agrument1,agrument2)
# Out:
# siwa rat

# %% [markdown]
# Pandas
# ## ***New Section***

# %%
import pandas as pd
names = ["First","ป้อม","พาส","Nan","นายก"] 
heights = [180,158,172,170,172]

series = pd.Series(heights, names)
series[1:4]

# series[[0,2,4]]

# series[[True,True,True,False,True]]
# series[(series > 170)]

# series["ger"] = 2

# type(series)
# Out:
# ป้อม    158
# พาส     172
# Nan     170
# dtype: int64

# %% [markdown]
# Lab Easy series
#
# 1)สร้างseries weight
#
# 2)สร้างseries height
#
# 3)นำมาบวกกัน
#
# 4) เพิ่มนำ้หนักของเพื่อน 1 คนในข้อ 2

# %%
friend_name  = ["A","B","C","D","F"]
weight_fri = [50,60,70,80,85]
height_fri = [170,175,180,185,190]
series1 = pd.Series(weight_fri,friend_name)
series2 = pd.Series(height_fri,friend_name)
series3 = pd.Series(series1+series2,friend_name)
print(series3)


series2["ger"] = 160
print("min of height=",series2.min())
print("max of height=",series2.max())
print("aver of height =",series2.mean())


print("min of weight=",series1.min())
print("max of weight=",series1.max())
print("aver of weight =",series1.mean())
# Out:
# A    220
# B    235
# C    250
# D    265
# F    275
# dtype: int64
# min of height= 160
# max of height= 190
# aver of height = 176.66666666666666
# min of weight= 50
# max of weight= 85
# aver of weight = 69.0

# %% [markdown]
# ## ***Dataframe***

# %%
names = ["First","ป้อม","พาส","Nan","นายก"] 
cols = ["Height","Weight"]
height_weight = [[180,72],[158,50],[172,55],[170,65],[172,90]]
df = pd.DataFrame(height_weight,names,cols)
df_tall_person = df[df["Height"]>170]
df_tall_person[["Height","Weight"]]
# Out:
#        Height  Weight
# First     180      72
# พาส       172      55
# นายก      172      90

# %% [markdown]
# dataframe โจทย์
#
# 1) เพิ้ม column เข้าไป โดยที column คือ อายุมัวๆ
#
# 2)find old>30years
#
# 3)print df_old[["Height","age"]]

# %%
names = ["First","ป้อม","พาส","Nan","นายก"] 
cols = ["Height","Weight","age"]
height_weight_age = [[180,72,32],[158,50,11],[172,55,17],[170,65,19],[172,90,22]]
df = pd.DataFrame(height_weight_age,names,cols)
df_old = df[df["age"]>30]
df_old[["Height","age"]]
# Out:
#        Height  age
# First     180   32

# %%
df = pd.read_csv("https://raw.githubusercontent.com/st119848/dataset/master/Automobile_data.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0            two  convertible          rwd           front        88.6  ...
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base  ...    city-mpg  highway-mpg
# count  205.000000  205.000000  ...  205.000000   205.000000
# mean     0.834146   98.756585  ...   25.219512    30.751220
# std      1.245307    6.021776  ...    6.542142     6.886443
# min     -2.000000   86.600000  ...   13.000000    16.000000
# 25%      0.000000   94.500000  ...   19.000000    25.000000
# 50%      1.000000   97.000000  ...   24.000000    30.000000
# 75%      2.000000  102.400000  ...   30.000000    34.000000
# max      3.000000  120.900000  ...   49.000000    54.000000
#
# [8 rows x 10 columns]

# %%
df_make = df.groupby('make')
df_make.describe()
# Out:
#               symboling                                                 \
#                   count      mean       std  min   25%  50%   75%  max
# make
# alfa-romero         3.0  2.333333  1.154701  1.0  2.00  3.0  3.00  3.0
# audi                7.0  1.285714  0.755929  0.0  1.00  1.0  2.00  2.0
# bmw                 8.0  0.375000  0.744024  0.0  0.00  0.0  0.25  2.0
# chevrolet           3.0  1.000000  1.000000  0.0  0.50  1.0  1.50  2.0
# dodge               9.0  1.000000  1.000000 -1.0  1.00  1.0  1.00  3.0
# honda              13.0  0.615385  0.767948  0.0  0.00  0.0  1.00  2.0
# isuzu               4.0  0.750000  0.957427  0.0  0.00  0.5  1.25  2.0
# jaguar              3.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# mazda              17.0  1.117647  1.166316  0.0  0.00  1.0  1.00  3.0
# mercedes-benz       8.0  0.000000  1.414214 -1.0 -1.00 -0.5  0.25  3.0
# mercury             1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0
# ...

# %%
print(df['make'].unique())
print(df['fuel-type'].unique())
print(df['num-of-doors'].unique())
# Out:
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# ['gas' 'diesel']
# ['two' 'four' '?']

# %% [markdown]
# ## ***Matplotlib***

# %%
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
x = [int(x) for x in range(10)]
y= [int(i)**2 for i in x]
plt.plot(x,y)
plt.show()

# %%
height = [160,170,180,190,200]
weight = [60,70,80,90,100]
plt.bar(height,weight)
plt.show()

# %% [markdown]
# ## ***Seaborn ***

# %%
import seaborn as sns
heights = [160,170,180,190,200]
names = ['a','b','c','d','f']

sns.barplot(names,heights)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df = pd.read_csv("https://raw.githubusercontent.com/st119848/dataset/master/Automobile_data.csv")
sns.countplot(x='make',data= df)
